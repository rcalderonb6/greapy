# %% [markdown]
# # Sampling from the posterior distribution with `Cobaya`

# %% [markdown]
# We also provide a wrapper for `Cobaya`. You can use it by mentioning it in the `theory` block.

# %%
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['mathtext.fontset'] = 'stix'
mpl.rcParams['font.family'] = 'STIXGeneral'
mpl.rcParams['axes.unicode_minus'] = False
mpl.rcParams['text.usetex'] = False  # Set to True if you have LaTeX installed

# %%
info={}
info['theory']={'greapy.cobaya.GREA': None}

info['sampler'] = {'mcmc': {'Rminus1_stop':0.1,'Rminus1_cl_stop':0.5,'max_tries':5_000}}
info['output'] = None

# %% [markdown]
# ### Likelihood
#
# Next, we specify the likelihood. In this example, we use DESI DR1, but any likelihood installed in Cobaya will do.

# %%
info['likelihood']={'bao.desi_2024_bao_all': None}

# %% [markdown]
# ### Priors

# %%
info['params']={
    # Sampled parameters
    'h': {'prior': [0.6, 0.8], 'latex': r'$h$'},
    'omega_cdm': {'prior': [0.1, 0.5], 'latex': r'$\omega_{\rm cdm}$'},
    'omega_b': {'prior': [0.01, 0.1], 'latex': r'$\omega_{\rm b}$'},
    'kappa': {'prior': [2.0, 5.0], 'latex': r'$\sqrt{-k}\eta_0$'},
    # Derived parameters
    'alpha': {'latex': r'$\alpha$'},
    'H0': {'latex': r'$H_0$'},
    'Omega_m': {'latex': r'$\Omega_m$'},
    'rdrag': {'latex': r'$r_{\rm d}$'},
    # Fixed parameters
    'Neff': 3.044
    }

# %% [markdown]
# ### Sampling

# %%
from cobaya.run import run
updated_info, sampler = run(info)
# Out:
# [bao.desi_2024_bao_all] Initialized.
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [mcmc] Initial point: h:0.7292459, omega_cdm:0.4326883, omega_b:0.02035322, kappa:4.601771
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {bao.desi_2024_bao_all: 1820.0, greapy.cobaya.GREA: 107.0}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Sampling!
# [mcmc] Progress @ 2025-07-20 15:02:35 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.015
# [mcmc]  - Convergence of means: R-1 = 2.743426 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.034
# [mcmc]  - Convergence of means: R-1 = 0.691681 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.066
# [mcmc]  - Convergence of means: R-1 = 0.204402 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.106
# [mcmc]  - Convergence of means: R-1 = 0.172657 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.160
# [mcmc]  - Convergence of means: R-1 = 0.177808 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.162
# [mcmc]  - Convergence of means: R-1 = 0.112280 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.161
# [mcmc]  - Convergence of means: R-1 = 0.132580 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.160
# [mcmc]  - Convergence of means: R-1 = 0.112848 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.158
# [mcmc]  - Convergence of means: R-1 = 0.096089 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1600 samples accepted.
# [mcmc]  - Acceptance rate: 0.163
# [mcmc]  - Convergence of means: R-1 = 0.106368 after 1280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [mcmc]  - Acceptance rate: 0.163
# [mcmc]  - Convergence of means: R-1 = 0.098175 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2025-07-20 15:03:35 : 19602 steps taken, and 1832 accepted.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.164
# [mcmc]  - Convergence of means: R-1 = 0.055885 after 1536 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.223894 after 1920 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 1920 accepted steps.

# %%
# Export the results to GetDist
dr1_samples= sampler.products(to_getdist=True,skip_samples=0.3)["sample"]

import getdist.plots as gdplt
# %matplotlib notebook

gdplot = gdplt.get_subplot_plotter()
gdplot.triangle_plot(dr1_samples, ["H0","Omega_m", "kappa","alpha"], filled=True)
# Out:
# [root] *WARNING* outlier fraction 0.06101190476190476

# %% [markdown]
# ### Updated constraints with DESI DR2
#
# Repeating the analysis with DESI DR2 instead is as simple as changing the likelihood

# %%
dr2_info=info.copy() # Copy run settings from DR1
dr2_info['likelihood']={'bao.desi_dr2': None} # Update likelihood to DESI DR2
updated_dr2_info, dr2_sampler = run(dr2_info) # Start the sampling
# Out:
# [bao.desi_dr2] Initialized.
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [mcmc] Initial point: h:0.6426293, omega_cdm:0.4554333, omega_b:0.0290452, kappa:2.132855
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {bao.desi_dr2: 2050.0, greapy.cobaya.GREA: 82.7}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Sampling!
# [mcmc] Progress @ 2025-07-20 15:07:06 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.008
# [mcmc]  - Convergence of means: R-1 = 1.137087 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.019
# [mcmc]  - Convergence of means: R-1 = 11.851717 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.036
# [mcmc]  - Convergence of means: R-1 = 1.999168 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2025-07-20 15:08:06 : 20328 steps taken, and 543 accepted.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.065
# [mcmc]  - Convergence of means: R-1 = 0.472885 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.200
# [mcmc]  - Convergence of means: R-1 = 0.488459 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.194
# [mcmc]  - Convergence of means: R-1 = 0.358025 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.181
# [mcmc]  - Convergence of means: R-1 = 0.516279 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.179
# [mcmc]  - Convergence of means: R-1 = 0.148338 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.176
# [mcmc]  - Convergence of means: R-1 = 0.288836 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1600 samples accepted.
# [mcmc]  - Acceptance rate: 0.171
# [mcmc]  - Convergence of means: R-1 = 0.197782 after 1280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [mcmc]  - Acceptance rate: 0.165
# [mcmc]  - Convergence of means: R-1 = 0.191117 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.163
# [mcmc]  - Convergence of means: R-1 = 0.147957 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2080 samples accepted.
# [mcmc]  - Acceptance rate: 0.161
# [mcmc]  - Convergence of means: R-1 = 0.121951 after 1664 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2240 samples accepted.
# [mcmc]  - Acceptance rate: 0.158
# [mcmc]  - Convergence of means: R-1 = 0.146432 after 1792 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2400 samples accepted.
# [mcmc]  - Acceptance rate: 0.156
# [mcmc]  - Convergence of means: R-1 = 0.126705 after 1920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2560 samples accepted.
# [mcmc]  - Acceptance rate: 0.155
# [mcmc]  - Convergence of means: R-1 = 0.021246 after 2048 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2720 samples accepted.
# [mcmc]  - Acceptance rate: 0.153
# [mcmc]  - Convergence of means: R-1 = 0.052814 after 2176 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.193683 after 2720 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 2720 accepted steps.

# %%
# %matplotlib notebook
dr2_samples= dr2_sampler.products(to_getdist=True,skip_samples=0.3)["sample"]

gdplot = gdplt.get_subplot_plotter()
gdplot.triangle_plot(dr2_samples, ["H0","Omega_m", "kappa","alpha"], filled=True)
# Out:
# [root] *WARNING* outlier fraction 0.022058823529411766

# %% [markdown]
# ### DR1 vs DR2

# %%
# %matplotlib notebook
gdplot = gdplt.get_subplot_plotter()
gdplot.triangle_plot([dr1_samples,dr2_samples], ["H0","Omega_m", "kappa","alpha"], filled=True, legend_labels=["DESI DR1","DESI DR2"], legend_loc='upper right'  )
